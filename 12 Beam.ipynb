# %%
import torch 
# batch_size, tokens, vocab_size
logits = torch.rand(4, 5, 10)
probs = torch.softmax(logits, dim=-1)
probs
# Out:
# tensor([[[0.0791, 0.1047, 0.0712, 0.1139, 0.1072, 0.0839, 0.1338, 0.0979,
#           0.0605, 0.1478],
#          [0.0686, 0.1633, 0.0778, 0.0933, 0.1025, 0.0943, 0.0824, 0.0640,
#           0.1332, 0.1205],
#          [0.0938, 0.0607, 0.0848, 0.1212, 0.1483, 0.1262, 0.1040, 0.0700,
#           0.0654, 0.1256],
#          [0.0987, 0.0839, 0.1291, 0.1457, 0.0760, 0.0962, 0.1093, 0.0841,
#           0.1192, 0.0579],
#          [0.0812, 0.1444, 0.1062, 0.1433, 0.0637, 0.1292, 0.0638, 0.0722,
#           0.0849, 0.1110]],
#
#         [[0.0730, 0.1184, 0.1316, 0.0980, 0.1182, 0.0719, 0.1108, 0.0597,
#           0.1384, 0.0800],
#          [0.0968, 0.0979, 0.1468, 0.0883, 0.0648, 0.0709, 0.1444, 0.1085,
#           0.0842, 0.0975],
#          [0.0744, 0.1143, 0.1087, 0.1079, 0.1274, 0.1170, 0.0579, 0.0740,
#           0.1417, 0.0767],
#          [0.0689, 0.0850, 0.0695, 0.0842, 0.0719, 0.0700, 0.1780, 0.1618,
#           0.1110, 0.0998],
# ...
